# %%
import numpy as np
import math

# %%
from PIL import Image
from IPython.display import display

im = Image.open("readonly/carlos.jpeg").convert('L')
print("origin size", im.size)
im = im.resize((200, 200))
display(im)
# Out:
# origin size (782, 1080)
# <PIL.Image.Image image mode=L size=200x200 at 0x25F7B6DCE50>

# %%
array = np.array(im)
print(array.shape)
array
# Out:
# (200, 200)
# array([[239, 239, 239, ..., 239, 239, 239],
#        [239, 239, 239, ..., 239, 239, 239],
#        [239, 239, 239, ..., 239, 239, 239],
#        ...,
#        [ 86,  80,  79, ...,  98, 144, 129],
#        [ 82,  76,  74, ...,  89, 137, 126],
#        [ 77,  73,  68, ...,  67, 111,  97]], dtype=uint8)

# %%
mask = np.full(array.shape, 255)
mask
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]])

# %%
modified_array = array - mask
modified_array =  modified_array*-1
modified_array = modified_array.astype(np.uint8)
modified_array
# Out:
# array([[ 16,  16,  16, ...,  16,  16,  16],
#        [ 16,  16,  16, ...,  16,  16,  16],
#        [ 16,  16,  16, ...,  16,  16,  16],
#        ...,
#        [169, 175, 176, ..., 157, 111, 126],
#        [173, 179, 181, ..., 166, 118, 129],
#        [178, 182, 187, ..., 188, 144, 158]], dtype=uint8)

# %%
display(Image.fromarray(modified_array))
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x25F7B6F9970>

# %%
print(modified_array.shape)
reshaped = np.reshape(modified_array, (100, 400))
print(reshaped.shape)
display(Image.fromarray(reshaped))
# Out:
# (200, 200)
# (100, 400)
# <PIL.Image.Image image mode=L size=400x100 at 0x25F7B6F9FA0>

# %% [markdown]
# # Indexing
