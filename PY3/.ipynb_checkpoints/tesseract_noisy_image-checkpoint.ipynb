# %%
from PIL import Image
from IPython.display import display

image = Image.open("readonly/Noisy_OCR.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=588x246 at 0x1EBFC642190>

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
text = pytesseract.image_to_string(image)
print(text)
# Out:
# e magic of OCR! Using pytesseract,
# le to read the contents of this
#
#
#
# d convert it to text

# %%
width, height = image.size
print(width)
# Out:
# 588

# %%
basewidth = 600
wpercent = (basewidth / float(width))
hsize = int((float(height) * float(wpercent)))

img = image.resize((basewidth, hsize), Image.ANTIALIAS)
img.save("readonly/resized_noise.png")

display(image)

text = pytesseract.image_to_string(Image.open("readonly/resized_noise.png"))
print(text)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=588x246 at 0x1EBFC642190>
# e magic of OCR! Using pytesseract,
# le to read the contents of this
# d convert it to text

# %%
gray_scale_img = image.convert("L")

gray_scale_img.save("readonly/gray_scale_noise.png")
text = pytesseract.image_to_string(Image.open("readonly/gray_scale_noise.png"))
print(text)
# Out:
# Behold, the magic of OCR! Using pytesseract,
# we'll be able to read the contents of this
# image and convert it to text

# %%
b_w_img = image.convert("1")

display(b_w_img)
# Out:
# <PIL.Image.Image image mode=1 size=588x246 at 0x1EBFC62D340>

# %%
def binalize(image_to_transform, threshold):
    output_image = image_to_transform.convert("L")
    width, height = output_image.size()
    for x in range(witdth):
        for y in range(height):
            if output_image.getpixel(x, y) < threshold:
                output_image.putpixel((x,y), 0)
            else:
                output_image.putpixel((x,y), 255)
    
    return output_image

for t in range(0, 257, 64):
    print("treshold====", t)
    display(binalize(image, t))
    print(pytesseract.image_to_string(binalize(image, t)))
# Out:
# treshold==== 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\Image.py in convert(self, mode, matrix, dither, palette, colors)
#    1025         try:
# -> 1026             im = self.im.convert(mode, dither)
#    1027         except ValueError:
#
# ValueError: conversion from RGBA to l not supported
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-617c958607d2> in <module>
#      13 for t in range(0, 257, 64):
#      14     print("treshold====", t)
# ---> 15     display(binalize(image, t))
#      16     print(pytesseract.image_to_string(binalize(image, t)))
#
# <ipython-input-16-617c958607d2> in binalize(image_to_transform, threshold)
#       1 def binalize(image_to_transform, threshold):
# ...
